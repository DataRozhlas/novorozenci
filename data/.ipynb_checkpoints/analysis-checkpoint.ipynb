# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
table = pd.read_csv('data.csv', index_col='JMÉNO')[:-1]

# %%
# počet unikátních jmen
for year in range(1916,2017):
    print(np.sum(table[str(year)].values!=0),end=",")
# Out:
# 86,132,141,223,269,366,435,537,605,650,730,782,888,953,1038,1081,1128,1177,1227,1267,1290,1334,1420,1440,1569,1585,1602,1687,1739,1669,1746,1684,1715,1734,1677,1696,1726,1670,1671,1641,1632,1637,1566,1548,1568,1575,1624,1680,1739,1742,1737,1669,1771,1792,1826,1839,1867,1803,1903,1896,1831,1778,1756,1744,1712,1654,1616,1559,1604,1640,1636,1701,1647,1786,1808,1988,2260,2263,2289,2300,2288,2343,2341,2190,2474,3500,3804,4026,4278,4647,5280,5578,6303,6434,6320,6159,6231,6219,6157,6198,5558,

# %%
# mediánový věk pro jméno
def get_median(name):
    subtable = table.loc[name].loc["1916":"2016"]
    year = 1916
    median_list = []
    for entry in subtable:
        for i in range(int(entry)):
            median_list.append(int(year))
        year+=1

    return median_list[round(len(median_list)/4)], median_list[round(len(median_list)/2)], median_list[3*round(len(median_list)/4)]

# %%
namecount = 0
name_medians = {}
for name, row in table.iterrows():
    if row["3000"] >= 500:
        namecount += 1
        name_medians[name] = get_median(name)
print(namecount)
# Out:
# 543

# %%
medians_sorted = sorted(name_medians, key=lambda x: name_medians[x][1])

# nejstarší jména (podle medianu)
for name in medians_sorted[:40]:
    print("[" + str(2017-name_medians[name][2]) + ", " +str(2017-name_medians[name][0]) + "//" + name)
    #2017-name_medians[name][1]
# Out:
# 7287//JIŘINKA
# 7386//ALOISIE
# 7585//HILDEGARDA
# 7183//ALENKA
# 7083//DANUŠKA
# 7484//GERTRUDA
# 7084//HILDA
# 7281//INGEBORG
# 6985//OTILIE
# 6484//CECILIE
# 6884//JOSEFA
# 6683//FRANTIŠKA
# 6778//HELGA
# 5583//HERMÍNA
# 6685//VĚROSLAVA
# 6983//MILUŠKA
# 6179//ADOLF
# 6479//EMILIA
# 6581//EMILIE
# 5977//GERHARD
# 6883//JARUŠKA
# 6779//JOZEFA
# 6680//LIDMILA
# 6381//BEDŘIŠKA
# 6481//BLAŽENA
# 6481//BOŽENA
# 6779//MILÁN
# 5277//WALTER
# 6176//KRISTA
# 6180//RŮŽENA
# 6579//VĚNCESLAVA
# 6480//VOJTĚŠKA
# 6180//DOBROSLAVA
# 5577//HERBERT
# 6773//IVANKA
# 5578//ALFRED
# 5081//ANDĚLA
# 6078//KVĚTOSLAVA
# 5578//MARIA
# 5977//MARIE

# %%
# nejmladší jména (podle medianu)
for name in medians_sorted[-25:]:
    if name != "NEZJIŠTĚNO":
        print(name, name_medians[name][1])
# Out:
# SEBASTIAN 2011
# SEBASTIÁN 2011
# VICTORIA 2011
# ADINA 2012
# DAMIÁN 2012
# EMMA 2012
# ISABELLA 2012
# JASMÍNA 2012
# LEONTÝNA 2012
# LILIANA 2012
# SOFIE 2012
# STELA 2012
# STELLA 2012
# TEODOR 2012
# TOBIAS 2012
# TOBIÁŠ 2012
# VOJTA 2012
# ELIÁŠ 2013
# ELLA 2013
# EMILY 2013
# MIA 2013
# ROZÁRIE 2013
# THEA 2013
# ZOE 2013
# LILIEN 2014

# %%
# nejmenší a největší spread
spread = {}
for name in name_medians:
    spread[name] = int(name_medians[name][2])-int(name_medians[name][0])
spread = sorted(spread, key=lambda x: int(spread[x]))
for name in spread[-100:]:
        print(name, name_medians[name][0], name_medians[name][2], int(name_medians[name][2])-int(name_medians[name][0]))
# Out:
# KATARÍNA 1952 1979 27
